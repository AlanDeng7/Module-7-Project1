# %%
#Dependencies
from __future__ import print_function
import argparse
import json
import pprint
import requests
import sys
import urllib
from config import api_key

# %%
try:
    # For Python 3.0 and later
    from urllib.error import HTTPError
    from urllib.parse import quote
    from urllib.parse import urlencode
except ImportError:
    # Fall back to Python 2's urllib2 and urllib
    from urllib2 import HTTPError
    from urllib import quote
    from urllib import urlencode

# %%
#API key from own python file
API_KEY= api_key

# API constants: Base url, search path, business path .
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  # Business ID will come after slash.


# Defaults for our simple example.
DEFAULT_TERM = 'dinner'
DEFAULT_LOCATION = 'Toronto, ON'
SEARCH_LIMIT = 50

# %%
def request(host, path, api_key, url_params=None):
    """Given your API_KEY, send a GET request to the API.
    Args:
        host (str): The domain host of the API.
        path (str): The path of the API after the domain.
        API_KEY (str): Your API Key.
        url_params (dict): An optional set of query parameters in the request.
    Returns:
        dict: The JSON response from the request.
    Raises:
        HTTPError: An error occurs from the HTTP request.
    """
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }

    print(u'Querying {0} ...'.format(url))

    response = requests.request('GET', url, headers=headers, params=url_params)

    return response.json()

# %%
def search(api_key, term, location):
    """Query the Search API by a search term and location.
    Args:
        term (str): The search term passed to the API.
        location (str): The search location passed to the API.
    Returns:
        dict: The JSON response from the request.
    """

    for offset in range(0,100,50):
        url_params = {
            'term': term.replace(' ', '+'),
            'location': location.replace(' ', '+'),
            'limit': SEARCH_LIMIT,
            'offset': offset

    }
    return request(API_HOST, SEARCH_PATH, api_key, url_params=url_params)

# %%
search(api_key,"restaurant", "toronto")
# Out:
# Querying https://api.yelp.com/v3/businesses/search ...
# {'businesses': [{'id': 'PyjnsWzNUTo1n2ohq0QznA',
#    'alias': 'dirty-food-eatery-toronto',
#    'name': 'Dirty Food Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3wGf7JV5CTv-H76aaScVww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dirty-food-eatery-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 130,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'southern', 'title': 'Southern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.66565, 'longitude': -79.47188},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3070 Dundas Street W',
#     'address2': None,
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6P 1Z7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['3070 Dundas Street W',
#      'Toronto, ON M6P 1Z7',
#      'Canada']},
#    'phone': '+14168553393',
#    'display_phone': '+1 416-855-3393',
#    'distance': 6115.64791765918},
#   {'id': 'a9U-swHFzq_6IZVOuawWQQ',
#    'alias': 'sinjeon-topokki-toronto',
#    'name': 'Sinjeon Topokki',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z4XlPKfztBRmmI4W0WIr4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sinjeon-topokki-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 2,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.66122, 'longitude': -79.37873},
#    'transactions': [],
#    'location': {'address1': '377 Church Street',
#     'address2': 'Unit 1',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5B 1H9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['377 Church Street',
#      'Unit 1',
#      'Toronto, ON M5B 1H9',
#      'Canada']},
#    'phone': '+14165910676',
#    'display_phone': '+1 416-591-0676',
#    'distance': 2056.6974881557953},
#   {'id': '47wBHgBwQ8_70sjmXow_1g',
#    'alias': 'her-fathers-cider-bar-and-kitchen-toronto',
#    'name': "Her Father's Cider Bar & Kitchen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1ElufiJeX8BzW-oSEqffpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/her-fathers-cider-bar-and-kitchen-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 183,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.66232, 'longitude': -79.40453},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '119 Harbord Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5S 1G7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['119 Harbord Street',
#      'Toronto, ON M5S 1G7',
#      'Canada']},
#    'phone': '+16473477747',
#    'display_phone': '+1 647-347-7747',
#    'distance': 1467.9214664770316},
#   {'id': '7UBOtHkr8dd1glP634Kkjw',
#    'alias': 'eataly-toronto-toronto-3',
#    'name': 'Eataly Toronto',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8xun4GxCLqpqZgTozhslSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eataly-toronto-toronto-3?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 270,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.6696154170451,
#     'longitude': -79.3887948598768},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '55 Bloor Street W',
#     'address2': '',
#     'address3': 'Manulife Centre',
#     'city': 'Toronto',
#     'zip_code': 'M4W 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['55 Bloor Street W',
#      'Manulife Centre',
#      'Toronto, ON M4W 1A6',
#      'Canada']},
#    'phone': '+14373740250',
#    'display_phone': '+1 437-374-0250',
#    'distance': 828.1659985341682},
#   {'id': 'moOwHq7SBQSgfkNIWaJQ7w',
#    'alias': 'bar-chica-toronto',
#    'name': 'Bar Chica',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nppy8BadWhy7Wxv-RcoULA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-chica-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 14,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.643879890618265,
#     'longitude': -79.39968413704536},
#    'transactions': [],
#    'location': {'address1': '75 Portland Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5V 2M9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['75 Portland Street',
#      'Toronto, ON M5V 2M9',
#      'Canada']},
#    'phone': '+14164799779',
#    'display_phone': '+1 416-479-9779',
#    'distance': 3388.3955229042654},
#   {'id': 'PiLfiQYyDNgBaAvSL58cqg',
#    'alias': 'okonomi-house-restaurant-toronto',
#    'name': 'Okonomi House Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5-xQPBtA9jH-g1tlmWKUhg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/okonomi-house-restaurant-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 309,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.668311069021, 'longitude': -79.387133746804},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '23 Charles Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M4Y 2R4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['23 Charles Street W',
#      'Toronto, ON M4Y 2R4',
#      'Canada']},
#    'phone': '+14169256176',
#    'display_phone': '+1 416-925-6176',
#    'distance': 1023.5909526297271},
#   {'id': 'mBOIef7a4hONEbSi_ai8Bw',
#    'alias': 'beast-bodega-toronto-2',
#    'name': 'Beast Bodega',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zoIk73jEF5icG7NjUl8I2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beast-bodega-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 413,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.64408, 'longitude': -79.40578},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '96 Tecumseth Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6J 2H1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['96 Tecumseth Street',
#      'Toronto, ON M6J 2H1',
#      'Canada']},
#    'phone': '+16473526000',
#    'display_phone': '+1 647-352-6000',
#    'distance': 3434.543042246412},
#   {'id': 'RmRgeuMoSL1RRiT7tokCPg',
#    'alias': 'mogouyuan-hand-pulled-noodles-toronto-2',
#    'name': 'Mogouyuan Hand-Pulled Noodles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cXENGSTT20YpDpDVoaE-CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mogouyuan-hand-pulled-noodles-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 77,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.66943, 'longitude': -79.38671},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '760 Yonge St',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M4Y 2B6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['760 Yonge St', 'Toronto, ON M4Y 2B6', 'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 980.9811276512088},
#   {'id': 'e41TP5cXZqSrz50xCBJqZw',
#    'alias': 'insomnia-restaurant-and-lounge-toronto',
#    'name': 'Insomnia Restaurant & Lounge',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XVJEYG8IZUuxye-bSrjvzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/insomnia-restaurant-and-lounge-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 1009,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.665961, 'longitude': -79.411003},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '563 Bloor Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5S 1Y6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['563 Bloor Street W',
#      'Toronto, ON M5S 1Y6',
#      'Canada']},
#    'phone': '+14165883907',
#    'display_phone': '+1 416-588-3907',
#    'distance': 1468.7971044745764},
#   {'id': 'KxHDiCOhHWQu_VOw8DMfJA',
#    'alias': 'the-hole-in-the-wall-toronto',
#    'name': 'The Hole In the Wall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j8AaN-VoAkUiYDo5JDvrqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hole-in-the-wall-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 169,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.66518, 'longitude': -79.46515},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2867 Dundas Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6P 1Y9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['2867 Dundas Street W',
#      'Toronto, ON M6P 1Y9',
#      'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5590.192935284379},
#   {'id': 'uGLAEGqeJa4jtP1Io0sOrg',
#    'alias': 'mineral-toronto',
#    'name': 'Mineral',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XmAvLOouyYHCDhtRkoAg1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mineral-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 18,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.67763, 'longitude': -79.38947},
#    'transactions': [],
#    'location': {'address1': '1027 Yonge Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M4W 2K9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1027 Yonge Street', 'Toronto, ON M4W 2K9', 'Canada']},
#    'phone': '+14169258565',
#    'display_phone': '+1 416-925-8565',
#    'distance': 700.2999061241129},
#   {'id': 'Je7jr840Ye6RWgSFhJ10MQ',
#    'alias': 'middle8-toronto',
#    'name': 'Middle8',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TLs-3ydF3XwdLTuqJ7g_SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/middle8-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 4,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.67064752093457, 'longitude': -79.3930014},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '119 Yorkville Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5R 1C4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['119 Yorkville Avenue',
#      'Toronto, ON M5R 1C4',
#      'Canada']},
#    'phone': '+16473438008',
#    'display_phone': '+1 647-343-8008',
#    'distance': 507.5903275009351},
#   {'id': 'EEIz44ewHhOKmfTloAK13g',
#    'alias': 'alo-restaurant-toronto',
#    'name': 'Alo Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wa3yNQpC4Img1jiAZkTrzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alo-restaurant-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 326,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.64851, 'longitude': -79.39584},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '163 Spadina Avenue',
#     'address2': '3rd Floor',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 2A5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['163 Spadina Avenue',
#      '3rd Floor',
#      'Toronto, ON M5V 2A5',
#      'Canada']},
#    'phone': '+14162602222',
#    'display_phone': '+1 416-260-2222',
#    'distance': 2861.5378545315702},
#   {'id': 'aLcFhMe6DDJ430zelCpd2A',
#    'alias': 'khao-san-road-toronto',
#    'name': 'Khao San Road',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ltk9xRcD5CusiPNJGMwogw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-san-road-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 1686,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.646412027881496,
#     'longitude': -79.39361985450327},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '11 Charlotte Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 2H5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['11 Charlotte Street',
#      'Toronto, ON M5V 2H5',
#      'Canada']},
#    'phone': '+16473525773',
#    'display_phone': '+1 647-352-5773',
#    'distance': 3109.667028077413},
#   {'id': 'ManqIzD8g7_mzzb_rY4iGw',
#    'alias': 'grandma-loves-you-toronto',
#    'name': 'Grandma Loves You',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TMbeW6t9IC9P20sshkYvmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grandma-loves-you-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 72,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.677846, 'longitude': -79.3901081050852},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1084 Yonge Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M4W 2L4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1084 Yonge Street', 'Toronto, ON M4W 2L4', 'Canada']},
#    'phone': '+14169255547',
#    'display_phone': '+1 416-925-5547',
#    'distance': 669.6489425025726},
#   {'id': 'LBQD0H2109oltJNF1raLWA',
#    'alias': 'the-haam-toronto-5',
#    'name': 'The Haam',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/diWAau3zlIoc-UwEIoXd4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-haam-toronto-5?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 303,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.64743, 'longitude': -79.39308},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '342 Adelaide St W',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5V 1R7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['342 Adelaide St W', 'Toronto, ON M5V 1R7', 'Canada']},
#    'phone': '+14169777258',
#    'display_phone': '+1 416-977-7258',
#    'distance': 3005.3070225618712},
#   {'id': 'snw9iNNLpFYZeHotW00uVA',
#    'alias': 'lee-restaurant-toronto-3',
#    'name': 'Lee Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zx0aFKfzKVihu3dn1POGSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lee-restaurant-toronto-3?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 706,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.644144, 'longitude': -79.400384},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '601 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 1M5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['601 King Street W', 'Toronto, ON M5V 1M5', 'Canada']},
#    'phone': '+14165047867',
#    'display_phone': '+1 416-504-7867',
#    'distance': 3363.4271111573235},
#   {'id': 'xK38ZXv5fE8YsRPCHg1sJw',
#    'alias': 'la-chingada-toronto',
#    'name': 'La Chingada',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TG3d0YqqKB_3qhbGW5Riqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-chingada-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 58,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.6495234427446,
#     'longitude': -79.4242079757355},
#    'transactions': [],
#    'location': {'address1': '1242 Dundas Street West',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M6J 1X5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1242 Dundas Street West',
#      'Toronto, ON M6J 1X5',
#      'Canada']},
#    'phone': '+14165352242',
#    'display_phone': '+1 416-535-2242',
#    'distance': 3526.02373311282},
#   {'id': 'AUejVfLtBF_aOFipdT2Rig',
#    'alias': 'le-swan-toronto',
#    'name': 'Le Swan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zy8MbCXT-EeURmWQadsn2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-swan-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 51,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.6452699, 'longitude': -79.4149},
#    'transactions': [],
#    'location': {'address1': '892 Queen St W',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M6J 1G3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['892 Queen St W', 'Toronto, ON M6J 1G3', 'Canada']},
#    'phone': '+14165364440',
#    'display_phone': '+1 416-536-4440',
#    'distance': 3551.519171472496},
#   {'id': 'q9_gLvTNf11etVxbH7JY0Q',
#    'alias': 'yasu-toronto-8',
#    'name': 'Yasu',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hp7IbcPV6iJV2jsS0qJDyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yasu-toronto-8?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 416,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.66269, 'longitude': -79.40314},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '81 Harbord Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5S 1G4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['81 Harbord Street', 'Toronto, ON M5S 1G4', 'Canada']},
#    'phone': '+14164772361',
#    'display_phone': '+1 416-477-2361',
#    'distance': 1382.2242471833936},
#   {'id': 'a-Mo7Ipu_c5y21mmg0-F7g',
#    'alias': 'agio-toronto',
#    'name': 'Agio',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vtzBtpuCPkG5XhTsL2Z22Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/agio-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 188,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.67599, 'longitude': -79.45066},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1351 St Clair Avenue W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6E 1C5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1351 St Clair Avenue W',
#      'Toronto, ON M6E 1C5',
#      'Canada']},
#    'phone': '+16473484814',
#    'display_phone': '+1 647-348-4814',
#    'distance': 4340.380082474621},
#   {'id': 'dvbcUnKv2awsIxog7dO4vw',
#    'alias': 'hong-kong-bistro-cafe-toronto',
#    'name': 'Hong Kong Bistro Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VY0LR9v8Ae4pY726FqJlwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hong-kong-bistro-cafe-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 118,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.65348, 'longitude': -79.39686},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '472 Dundas Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5T 1G8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['472 Dundas Street W',
#      'Toronto, ON M5T 1G8',
#      'Canada']},
#    'phone': '+14165989188',
#    'display_phone': '+1 416-598-9188',
#    'distance': 2316.9428329432785},
#   {'id': '-ltD-dHqdZ5-wjAMKYa6Ng',
#    'alias': 'la-bella-managua-toronto',
#    'name': 'La Bella Managua',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ucCHuXbDEBz5e2SQTGTMvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bella-managua-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 246,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'nicaraguan', 'title': 'Nicaraguan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.66232, 'longitude': -79.42495},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '872 Bloor Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6G 1M5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['872 Bloor Street W',
#      'Toronto, ON M6G 1M5',
#      'Canada']},
#    'phone': '+14169134227',
#    'display_phone': '+1 416-913-4227',
#    'distance': 2629.3945498196963},
#   {'id': 'LFthZhOBZWpdLmxO9XuvFQ',
#    'alias': 'adrak-toronto',
#    'name': 'Adrak',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AuwzE7OP2IT-qcAxFHm-Tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adrak-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 10,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.674422579004904,
#     'longitude': -79.39662899999999},
#    'transactions': [],
#    'location': {'address1': '138 Avenue Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5R 2H6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['138 Avenue Road', 'Toronto, ON M5R 2H6', 'Canada']},
#    'phone': '+14164130777',
#    'display_phone': '+1 416-413-0777',
#    'distance': 21.922268160583712},
#   {'id': 'BWCfyBdnTvuXp6A_8wt8cA',
#    'alias': 'ikkousha-ramen-toronto-4',
#    'name': 'Ikkousha Ramen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q-Sx02Qg6XgkEGUqqRV_Kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ikkousha-ramen-toronto-4?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 283,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.65024, 'longitude': -79.38873},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '249 Queen Street W',
#     'address2': None,
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 1Z4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['249 Queen Street W',
#      'Toronto, ON M5V 1Z4',
#      'Canada']},
#    'phone': '+14169012249',
#    'display_phone': '+1 416-901-2249',
#    'distance': 2750.2913795713343},
#   {'id': 'Q8TRdS59cq-ie8FqtpjEdQ',
#    'alias': 'maison-t-toronto',
#    'name': 'Maison T',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XNBcKocOgXV21x90dtsX8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maison-t-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 13,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.67052, 'longitude': -79.42632},
#    'transactions': [],
#    'location': {'address1': '1071 Shaw St',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M6G 3N4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1071 Shaw St', 'Toronto, ON M6G 3N4', 'Canada']},
#    'phone': '+14165519898',
#    'display_phone': '+1 416-551-9898',
#    'distance': 2409.520659410402},
#   {'id': 'iZ_Hdpxqwt3-c6349wXhuA',
#    'alias': 'jin-dal-lae-toronto',
#    'name': 'Jin Dal Lae',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Wh6c935K1Ttn-hfwtjfXFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jin-dal-lae-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 109,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.664166, 'longitude': -79.41517},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '647 Bloor Street W',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M6G 1L1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['647 Bloor Street W',
#      'Toronto, ON M6G 1L1',
#      'Canada']},
#    'phone': '+14165306974',
#    'display_phone': '+1 416-530-6974',
#    'distance': 1855.690445841759},
#   {'id': 'c78Pat78fVUBFPXYeVvbaQ',
#    'alias': 'oddseoul-toronto-2',
#    'name': 'Oddseoul',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_8wySzLNbV2FPjPL3m5xdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oddseoul-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 326,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.64617546167321,
#     'longitude': -79.41973480556406},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '90 Ossington Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6J 2Z4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['90 Ossington Avenue',
#      'Toronto, ON M6J 2Z4',
#      'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3628.414693928425},
#   {'id': '_Ar0rDN_xp9chIrCfRQ6vw',
#    'alias': 'ruby-soho-toronto',
#    'name': 'Ruby Soho',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ivkHno767JDt4XeiHOagww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ruby-soho-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 37,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.64423, 'longitude': -79.40015},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '587 King St W',
#     'address2': None,
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5V 1M5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['587 King St W', 'Toronto, ON M5V 1M5', 'Canada']},
#    'phone': '+14169017829',
#    'display_phone': '+1 416-901-7829',
#    'distance': 3357.0798040937416},
#   {'id': 'RKXrG6Gqp5SKl1WXG7Jlqg',
#    'alias': 'yuzuki-toronto',
#    'name': 'Yuzuki',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Dh1QAyLip0NB3aOyQB9r0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuzuki-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 39,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.6713124, 'longitude': -79.3838651},
#    'transactions': [],
#    'location': {'address1': '120 Bloor Street E',
#     'address2': 'Unit 104',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M4Y 0B8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['120 Bloor Street E',
#      'Unit 104',
#      'Toronto, ON M4Y 0B8',
#      'Canada']},
#    'phone': '+14169232997',
#    'display_phone': '+1 416-923-2997',
#    'distance': 1090.3385401632704},
#   {'id': 'hFbhRTodMqG2FAf0UWjJQw',
#    'alias': 'the-golden-pheasant-mississauga',
#    'name': 'The Golden Pheasant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8A59FR2GgeA38Z2b4Hedjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-golden-pheasant-mississauga?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 63,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.57077, 'longitude': -79.56565},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '733 Lakeshore Road E',
#     'address2': '',
#     'address3': '',
#     'city': 'Mississauga',
#     'zip_code': 'L5G 1J7',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['733 Lakeshore Road E',
#      'Mississauga, ON L5G 1J7',
#      'Canada']},
#    'phone': '+19057819374',
#    'display_phone': '+1 905-781-9374',
#    'distance': 17806.634555606994},
#   {'id': 'vvapae5E4fnZXWG8Wylzyw',
#    'alias': 'gyubee-japanese-grill-dundas-toronto',
#    'name': 'Gyubee Japanese Grill - Dundas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5Rro_wx7iUld5BJJnxqRpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gyubee-japanese-grill-dundas-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 162,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.6551427, 'longitude': -79.3857634},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '157 Dundas St W',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5B 1E4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['157 Dundas St W', 'Toronto, ON M5B 1E4', 'Canada']},
#    'phone': '+14166391545',
#    'display_phone': '+1 416-639-1545',
#    'distance': 2300.7325796924765},
#   {'id': 'ONCQS_-UjcHa_J4ueZG1Hw',
#    'alias': 'haidilao-hot-pot-toronto-2',
#    'name': 'Haidilao Hot Pot',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Is7fMbzkKqlDRHscOkqOLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haidilao-hot-pot-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 15,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.65463297669771,
#     'longitude': -79.37983900308609},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '237 Yonge Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5B 1N8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['237 Yonge Street', 'Toronto, ON M5B 1N8', 'Canada']},
#    'phone': '+14377781068',
#    'display_phone': '+1 437-778-1068',
#    'distance': 2576.6987722984018},
#   {'id': 'fobkeIEzbJtej-udG4UoRg',
#    'alias': 'madrina-bar-y-tapas-toronto-2',
#    'name': 'Madrina Bar y Tapas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GfIbxqGHn6OungmZZfpAow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madrina-bar-y-tapas-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 131,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.64971833602106,
#     'longitude': -79.35967868465576},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2 Trinity Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5A 3C4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['2 Trinity Street', 'Toronto, ON M5A 3C4', 'Canada']},
#    'phone': '+14165488055',
#    'display_phone': '+1 416-548-8055',
#    'distance': 4048.034401601027},
#   {'id': 'iJCI80Nwp514xIqBOgjhCA',
#    'alias': 'fat-pasha-toronto-2',
#    'name': 'Fat Pasha',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5ZTjFTonjEHzHSB0o8ZRGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fat-pasha-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 208,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.67387, 'longitude': -79.41171},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '414 Dupont Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5R 1V9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['414 Dupont Street', 'Toronto, ON M5R 1V9', 'Canada']},
#    'phone': '+16473406142',
#    'display_phone': '+1 647-340-6142',
#    'distance': 1199.7052375067974},
#   {'id': 'JG9UpsFR6hrqQqsKh_RyaQ',
#    'alias': 'planta-toronto-13',
#    'name': 'PLANTA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PZeryEMsHfd2gxRvB3iyhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planta-toronto-13?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 487,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6702150961667,
#     'longitude': -79.3894335574237},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1221 Bay Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5R 3P5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1221 Bay Street', 'Toronto, ON M5R 3P5', 'Canada']},
#    'phone': '+16478121221',
#    'display_phone': '+1 647-812-1221',
#    'distance': 746.61035273228},
#   {'id': '0a2O150ytxrDjDzXNfRWkA',
#    'alias': 'miku-toronto-2',
#    'name': 'Miku',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S-iX07CuKkgnk8Q7ECpnTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miku-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 878,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6412346, 'longitude': -79.3773697},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '105-10 Bay Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5J 2R8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['105-10 Bay Street', 'Toronto, ON M5J 2R8', 'Canada']},
#    'phone': '+16473477347',
#    'display_phone': '+1 647-347-7347',
#    'distance': 3993.962633165498},
#   {'id': 'jwgziERCc8jom4JfsPtzyA',
#    'alias': 'kibo-secret-garden-toronto-7',
#    'name': 'Kibo Secret Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d0BNb06YvW1Jv8Gs47NhtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kibo-secret-garden-toronto-7?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 25,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6700657, 'longitude': -79.3932832},
#    'transactions': [],
#    'location': {'address1': '154 Cumberland Street',
#     'address2': 'Upper Level',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5R 1A8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['154 Cumberland Street',
#      'Upper Level',
#      'Toronto, ON M5R 1A8',
#      'Canada']},
#    'phone': '+14165194580',
#    'display_phone': '+1 416-519-4580',
#    'distance': 546.4967969998042},
#   {'id': 'x0MaTw6He1w_1nddeSJU2Q',
#    'alias': 'the-roof-at-soco-toronto',
#    'name': 'The Roof at SOCO',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gF-WNQ01HKhpFM5ZIZNn3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-roof-at-soco-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 17,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.64303, 'longitude': -79.38379},
#    'transactions': [],
#    'location': {'address1': '75 Lower Simcoe Street',
#     'address2': 'Fourth Floor',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5J 3A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['75 Lower Simcoe Street',
#      'Fourth Floor',
#      'Toronto, ON M5J 3A6',
#      'Canada']},
#    'phone': '+14166375465',
#    'display_phone': '+1 416-637-5465',
#    'distance': 3635.150354336295},
#   {'id': 'nrq5H3LZicjMG0wv7gy08g',
#    'alias': 'kintaro-izakaya-toronto-3',
#    'name': 'Kintaro Izakaya',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DMcq7LEPwfRk4cqG3gvUsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kintaro-izakaya-toronto-3?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 232,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.66417, 'longitude': -79.38006},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '459 Church Street',
#     'address2': 'Main Floor',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M4Y 4C5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['459 Church Street',
#      'Main Floor',
#      'Toronto, ON M4Y 4C5',
#      'Canada']},
#    'phone': '+16475605335',
#    'display_phone': '+1 647-560-5335',
#    'distance': 1751.9094217306326},
#   {'id': 'RyDiwx4xD3Lx8sWHx1aFlQ',
#    'alias': 'smoque-n-bones-toronto',
#    'name': "Smoque N' Bones",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F20hMiGA1vesIvxF830CgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smoque-n-bones-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 410,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6457027819391,
#     'longitude': -79.4107432752393},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '869 Queen Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6J 1G4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['869 Queen Street W',
#      'Toronto, ON M6J 1G4',
#      'Canada']},
#    'phone': '+16473415730',
#    'display_phone': '+1 647-341-5730',
#    'distance': 3369.459360460426},
#   {'id': 'hFa8N5vDTApRnA3PCjWe4A',
#    'alias': 'tokyo-hot-fried-chicken-toronto',
#    'name': 'Tokyo Hot Fried Chicken',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2fWF_WyXEj3BN4xYQ-cYZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tokyo-hot-fried-chicken-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 45,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.655201668238774,
#     'longitude': -79.41637633067134},
#    'transactions': [],
#    'location': {'address1': '656 College Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M6G 1B8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['656 College Street',
#      'Toronto, ON M6G 1B8',
#      'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2641.1777780499388},
#   {'id': 'IhM1UBvAMM5Fia4f_v1wdQ',
#    'alias': 'el-nahual-tacos-toronto-7',
#    'name': 'El Nahual Tacos',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zSD6pNEgqBnBbRFZLRzTOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-nahual-tacos-toronto-7?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 147,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.666945, 'longitude': -79.36922000060865},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '556 parliament st',
#     'address2': None,
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5S 1X2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['556 parliament st', 'Toronto, ON M5S 1X2', 'Canada']},
#    'phone': '+14169641000',
#    'display_phone': '+1 416-964-1000',
#    'distance': 2365.030657436603},
#   {'id': '2KXuvIcFTSwSOFcdGv35gQ',
#    'alias': 'c-block-taiwanese-bento-toronto-2',
#    'name': 'C-Block Taiwanese Bento',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/exZSMmRHJITok7Vj2RGcyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/c-block-taiwanese-bento-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 3,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'panasian', 'title': 'Pan Asian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.664001, 'longitude': -79.41705},
#    'transactions': [],
#    'location': {'address1': '690 Bloor Street W',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M6G 1L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['690 Bloor Street W',
#      'Toronto, ON M6G 1L2',
#      'Canada']},
#    'phone': '+14165324118',
#    'display_phone': '+1 416-532-4118',
#    'distance': 1993.2777566433697},
#   {'id': 'HHvO4MgBFabsmlInou6viQ',
#    'alias': 'le-baratin-toronto-5',
#    'name': 'Le Baratin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1EXCZ47aOn1z1M5jkjvDZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-baratin-toronto-5?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 129,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.65007, 'longitude': -79.4351},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1600 Dundas Street. W',
#     'address2': None,
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6K 1T8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1600 Dundas Street. W',
#      'Toronto, ON M6K 1T8',
#      'Canada']},
#    'phone': '+14165348800',
#    'display_phone': '+1 416-534-8800',
#    'distance': 4092.028304682548},
#   {'id': 'sV4QGXQk77dmr-lqTcDTKQ',
#    'alias': 'rikki-tikki-toronto-2',
#    'name': 'Rikki Tikki',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9WBFEQhNpHfsYkZ2CBcmcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rikki-tikki-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 12,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.6540813, 'longitude': -79.4014858},
#    'transactions': [],
#    'location': {'address1': '209 Augusta Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5T 2L4',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['209 Augusta Avenue',
#      'Toronto, ON M5T 2L4',
#      'Canada']},
#    'phone': '+14167923229',
#    'display_phone': '+1 416-792-3229',
#    'distance': 2277.3470315305135},
#   {'id': 'qPVqfJAzC8APF8aWGBtFRA',
#    'alias': 'antler-kitchen-and-bar-toronto',
#    'name': 'Antler Kitchen & Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5JM3POlE0KmOVLAlOKzRfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/antler-kitchen-and-bar-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 285,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.64985, 'longitude': -79.43059},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1454 Dundas Street West',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6J 1Y6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1454 Dundas Street West',
#      'Toronto, ON M6J 1Y6',
#      'Canada']},
#    'phone': '+16473458300',
#    'display_phone': '+1 647-345-8300',
#    'distance': 3852.7090187319895},
#   {'id': 'cQK9M2JAwETQnnBoYyua5A',
#    'alias': 'the-senator-toronto',
#    'name': 'The Senator',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-YxCyds-0w13s0oGp88-Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-senator-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 489,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.65574, 'longitude': -79.37896},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '249 Victoria Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M5B 1T8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['249 Victoria Street',
#      'Toronto, ON M5B 1T8',
#      'Canada']},
#    'phone': '+14163647517',
#    'display_phone': '+1 416-364-7517',
#    'distance': 2510.620233780457},
#   {'id': 'sApPN_ZTcxtJO61xH9uPkg',
#    'alias': 'moon-palace-toronto-2',
#    'name': 'Moon Palace',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uzR0aAkEHkhYFtF1eT1M9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moon-palace-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 47,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.6561951, 'longitude': -79.38240341165705},
#    'transactions': [],
#    'location': {'address1': '40 Dundas Street W',
#     'address2': '',
#     'address3': None,
#     'city': 'Toronto',
#     'zip_code': 'M5G 2C2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['40 Dundas Street W',
#      'Toronto, ON M5G 2C2',
#      'Canada']},
#    'phone': '+14165515666',
#    'display_phone': '+1 416-551-5666',
#    'distance': 2321.5358908223166},
#   {'id': '3YKV1eralyrKQqoWOTJMDA',
#    'alias': 'giulietta-toronto',
#    'name': 'Giulietta',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iA8C5nwH8UJnzOV-aCPxAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giulietta-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#    'review_count': 123,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.65353, 'longitude': -79.42764},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '972 College Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Toronto',
#     'zip_code': 'M6H 1A5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['972 College Street',
#      'Toronto, ON M6H 1A5',
#      'Canada']},
#    'phone': '+14169640606',
#    'display_phone': '+1 416-964-0606',
#    'distance': 3389.8428726409315}],
#  'total': 9800,
#  'region': {'center': {'longitude': -79.39682006835938,
#    'latitude': 43.67428196976998}}}
