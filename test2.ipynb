# %%
#Dependencies
import json
import pprint
import requests
import pandas as pd 
from config import api_key

# %%
#function to find the restaurants. (location, term to search for, number of results,apikey)
def get_businesses(location, term,queries, api_key):
    headers = {'Authorization': 'Bearer %s' % api_key}
    url = 'https://api.yelp.com/v3/businesses/search'

    data = []
    for offset in range(0, queries, 50):
        params = {
            'limit': 50, 
            'location': location.replace(' ', '+'),
            'term': term.replace(' ', '+'),
            'offset': offset
        }

        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data += response.json()['businesses']
        elif response.status_code == 400:
            print('400 Bad Request')
            break

    return data

# %%
get_businesses("toronto","mcdonalds",50,api_key)
# Out:
# [{'id': '8OyEa0ArJe8r9CDAFmCUWg',
#   'alias': 'mcdonalds-toronto-50',
#   'name': 'Mcdonalds',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nCp9Jpci4wD4sZZagu8c4w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-50?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 4,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.7993663254906,
#    'longitude': -79.1995456069708},
#   'transactions': [],
#   'location': {'address1': '798 milner',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M1B 3C3',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['798 milner', 'Toronto, ON M1B 3C3', 'Canada']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 21086.70297271246},
#  {'id': 'xpeSmFl6yWWn8KGGUsb05g',
#   'alias': 'mcdonalds-toronto-129',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KBX6V6niAFAk2Ihn0EsnwA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-129?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 16,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.668633, 'longitude': -79.395159},
#   'transactions': [],
#   'location': {'address1': '196 Bloor Street W',
#    'address2': '',
#    'address3': None,
#    'city': 'Toronto',
#    'zip_code': 'M5T 1S8',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['196 Bloor Street W', 'Toronto, ON M5T 1S8', 'Canada']},
#   'phone': '+14169641583',
#   'display_phone': '+1 416-964-1583',
#   'distance': 642.1862170388009},
#  {'id': 'hi2EpaTqR9Wx-aj05-eyfg',
#   'alias': 'mcdonalds-toronto-74',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IzlEjPW7fwLTzVOiPo3R_g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-74?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 38,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 43.66884, 'longitude': -79.38594},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '675 Yonge Street',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4Y 1T2',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['675 Yonge Street', 'Toronto, ON M4Y 1T2', 'Canada']},
#   'phone': '+14164131442',
#   'display_phone': '+1 416-413-1442',
#   'distance': 1049.3547002378577},
#  {'id': 'K5u1029QHG4JkURRx_z7JA',
#   'alias': 'mcdonalds-toronto-99',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ICrrVWRkvM2dUkufnuL8cg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-99?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 18,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 43.6644688268878,
#    'longitude': -79.3846026381418},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '552 Yonge Street',
#    'address2': '',
#    'address3': None,
#    'city': 'Toronto',
#    'zip_code': 'M4Y 1Y8',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['552 Yonge Street', 'Toronto, ON M4Y 1Y8', 'Canada']},
#   'phone': '+14169247600',
#   'display_phone': '+1 416-924-7600',
#   'distance': 1468.427635738075},
#  {'id': '-IP0Y1XLcnxb6yfMxPcLfQ',
#   'alias': 'mcdonalds-toronto-72',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U6vAOG72y9IMIQz-fqU7dg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-72?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 20,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 43.67153, 'longitude': -79.37794},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '345 Bloor Street East',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4W 3J6',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['345 Bloor Street East',
#     'Toronto, ON M4W 3J6',
#     'Canada']},
#   'phone': '+14169671081',
#   'display_phone': '+1 416-967-1081',
#   'distance': 1509.9487136621397},
#  {'id': '2mKFNjIEktW2Nl1yV2cj7g',
#   'alias': 'mcdonalds-toronto-4',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wGgOiNhEhBxiHgjVMYErew/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-4?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 26,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 43.6880988, 'longitude': -79.3931787},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '11 St. Clair Ave East',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4T 1L8',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['11 St. Clair Ave East',
#     'Toronto, ON M4T 1L8',
#     'Canada']},
#   'phone': '+14163233173',
#   'display_phone': '+1 416-323-3173',
#   'distance': 1564.0159772079598},
#  {'id': 'KFaMIyNmxHeAot5huOiuyg',
#   'alias': 'mcdonalds-toronto-17',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xT4ptY9-xR_UfioTUJd1Bw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-17?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 42,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 43.66219, 'longitude': -79.38376},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '470 Yonge Street',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4Y 1X5',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['470 Yonge Street', 'Toronto, ON M4Y 1X5', 'Canada']},
#   'phone': '+14169222905',
#   'display_phone': '+1 416-922-2905',
#   'distance': 1704.9559068763215},
#  {'id': 'yLM3YK6sBM4xXpnF3ayGlw',
#   'alias': 'mcdonalds-toronto-59',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/m8B-RAvusR8JPxyW04MvZw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-59?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 21,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 43.6581832, 'longitude': -79.3820441},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '356 Yonge Street',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5B 1S5',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['356 Yonge Street', 'Toronto, ON M5B 1S5', 'Canada']},
#   'phone': '+14165962231',
#   'display_phone': '+1 416-596-2231',
#   'distance': 2148.72435086733},
#  {'id': 'ezFB98nX2V_E0B6HuKHl3A',
#   'alias': 'mcdonalds-toronto-111',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MVnyMwf3ezW3C2-u2OHlWA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-111?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 12,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 43.653756893306,
#    'longitude': -79.39092019581423},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '109 McCaul Street',
#    'address2': '',
#    'address3': None,
#    'city': 'Toronto',
#    'zip_code': 'M5T 3K5',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['109 McCaul Street', 'Toronto, ON M5T 3K5', 'Canada']},
#   'phone': '+14169776607',
#   'display_phone': '+1 416-977-6607',
#   'distance': 2331.1012753267855},
#  {'id': 'W6zJtBokhnJvpHlZbROBBQ',
#   'alias': 'mcdonalds-toronto-77',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hovuwudTW1jMnsdJppB1dg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-77?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 19,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 43.6544382, 'longitude': -79.3806994},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '260 Yonge Street',
#    'address2': 'Unit J-002',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5B 2L9',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['260 Yonge Street',
#     'Unit J-002',
#     'Toronto, ON M5B 2L9',
#     'Canada']},
#   'phone': '+14165979502',
#   'display_phone': '+1 416-597-9502',
#   'distance': 2559.3387432816326},
#  {'id': 'ATqO2OqqeZnctPD3JlkPhA',
#   'alias': 'mcdonalds-toronto-14',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5Ujq_-YYfNzjuefTi9xy7Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-14?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 14,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 43.68177335859725,
#    'longitude': -79.42692713144714},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '710 St Clair W',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M6C 1B2',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['710 St Clair W', 'Toronto, ON M6C 1B2', 'Canada']},
#   'phone': '+14166561702',
#   'display_phone': '+1 416-656-1702',
#   'distance': 2560.4883954291045},
#  {'id': 'bJm67R1YQUNius2OjEQ5rA',
#   'alias': 'mcdonalds-toronto-76',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V4saVmWTx3IHcSpNuQdk1g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-76?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 23,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 43.65207, 'longitude': -79.40613},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '344 Bathurst Street',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5T 2S3',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['344 Bathurst Street',
#     'Toronto, ON M5T 2S3',
#     'Canada']},
#   'phone': '+14163625499',
#   'display_phone': '+1 416-362-5499',
#   'distance': 2582.160342728516},
#  {'id': 'Aj1ocRaJoocaYEmfD5gjIQ',
#   'alias': 'mcdonalds-toronto-58',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TO800E8Cccb_sDnlWMWCDQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-toronto-58?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 12,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 43.6618106245332,
#    'longitude': -79.4253165915709},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '885 Bloor St West',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M6G 1M4',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['885 Bloor St West', 'Toronto, ON M6G 1M4', 'Canada']},
#   'phone': '+14165886724',
#   'display_phone': '+1 416-588-6724',
#   'distance': 2678.9209987164895},
#  {'id': 'bTJnd1cvOXO4_an4-442cQ',
#   'alias': 'chick-fil-a-toronto',
#   'name': 'Chick-fil-A',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h-n5PsvWnD8IsygzWtKTxQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chick-fil-a-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 115,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'chickenshop', 'title': 'Chicken Shop'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.669550169591965,
#    'longitude': -79.38614762542414},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '709 Yonge St',
#    'address2': '',
#    'address3': None,
#    'city': 'Toronto',
#    'zip_code': 'M4Y 2B6',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['709 Yonge St', 'Toronto, ON M4Y 2B6', 'Canada']},
#   'phone': '+13656010015',
#   'display_phone': '+1 365-601-0015',
#   'distance': 1006.7869304867401},
#  {'id': 'oWTn2IzrprsRkPfULtjZtQ',
#   'alias': 'the-burgers-priest-toronto',
#   'name': "The Burger's Priest",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bM8N4iMn3U6_BAy_vcawzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-burgers-priest-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 502,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.666699590075, 'longitude': -79.3155846030585},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1636 Queen Street E',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4L 1G3',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['1636 Queen Street E',
#     'Toronto, ON M4L 1G3',
#     'Canada']},
#   'phone': '+16473460617',
#   'display_phone': '+1 647-346-0617',
#   'distance': 6587.921493649847},
#  {'id': 'F9tePBgROEAcd8xZqTZUfg',
#   'alias': 'jollibee-scarborough-3',
#   'name': 'Jollibee',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4JMNV_Ks22O7v2G9zMrDJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jollibee-scarborough-3?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 299,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.7732069264407,
#    'longitude': -79.28106567544576},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '15 William Kitchen Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Scarborough',
#    'zip_code': 'M1P 5B7',
#    'country': 'CA',
#    'state': 'AB',
#    'display_address': ['15 William Kitchen Rd',
#     'Scarborough, AB M1P 5B7',
#     'Canada']},
#   'phone': '+16479531100',
#   'display_phone': '+1 647-953-1100',
#   'distance': 14405.647502331552},
#  {'id': 'YJ05ntGlszxACOD5zn1YjA',
#   'alias': 'the-burgers-priest-toronto-2',
#   'name': "The Burger's Priest",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/80huSKai3wzpj20TrNcE3Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-burgers-priest-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 421,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.6484032, 'longitude': -79.3972855},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '463 Queen Street W',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5V 2A9',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['463 Queen Street W', 'Toronto, ON M5V 2A9', 'Canada']},
#   'phone': '+16477488108',
#   'display_phone': '+1 647-748-8108',
#   'distance': 2877.8282719301556},
#  {'id': '5-KisjcYyWN6Fwcp-wDYmw',
#   'alias': 'urban-eatery-at-the-eaton-centre-toronto',
#   'name': 'Urban Eatery at the Eaton Centre',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DT-iYG5LrPyS-tbOcj39rA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/urban-eatery-at-the-eaton-centre-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 66,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.6557636172602,
#    'longitude': -79.3811774253845},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Eaton Centre',
#    'address2': '220 Yonge St, Ste 110',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5B 2L7',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['Eaton Centre',
#     '220 Yonge St, Ste 110',
#     'Toronto, ON M5B 2L7',
#     'Canada']},
#   'phone': '+14165988560',
#   'display_phone': '+1 416-598-8560',
#   'distance': 2413.144282575842},
#  {'id': 'xFkUn2tIJY0vkcm1Hl5m_A',
#   'alias': 'wahlburgers-toronto',
#   'name': 'Wahlburgers',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sENDIhG_ZQGr7BXoYyUdHQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wahlburgers-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 345,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 43.64510556333696,
#    'longitude': -79.39213710265176},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '46 Blue Jays Way',
#    'address2': '-',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5V 1J6',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['46 Blue Jays Way',
#     '-',
#     'Toronto, ON M5V 1J6',
#     'Canada']},
#   'phone': '+14164898922',
#   'display_phone': '+1 416-489-8922',
#   'distance': 3266.063377243407},
#  {'id': '67Pa_CtXthgJzXfY8JzLDQ',
#   'alias': 'holy-chuck-toronto',
#   'name': 'Holy Chuck',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MEvAXPvGQbqq4ymrqHJZ8Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/holy-chuck-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 348,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.68753, 'longitude': -79.39406},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1450 Yonge Street',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4T 1Y7',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['1450 Yonge Street', 'Toronto, ON M4T 1Y7', 'Canada']},
#   'phone': '+14169624825',
#   'display_phone': '+1 416-962-4825',
#   'distance': 1489.4543806858155},
#  {'id': 'r6pMpFJ2LFY_5cW_BMTOfQ',
#   'alias': 'matty-s-patty-s-burger-club-toronto',
#   'name': 'Matty’s Patty’s Burger Club',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nyglokeY4UhorjZruss9jw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/matty-s-patty-s-burger-club-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 57,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.6452257, 'longitude': -79.4126735},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '923a Queen St W',
#    'address2': '',
#    'address3': None,
#    'city': 'Toronto',
#    'zip_code': 'M6J 1G5',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['923a Queen St W', 'Toronto, ON M6J 1G5', 'Canada']},
#   'phone': '+14165468091',
#   'display_phone': '+1 416-546-8091',
#   'distance': 3468.432751106507},
#  {'id': '1SknhuCmaR0PIIjQY3e6eg',
#   'alias': 'the-burgers-priest-toronto-11',
#   'name': "The Burger's Priest",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hwnU3NlPSToruh1Biw3R6w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-burgers-priest-toronto-11?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 256,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.73258, 'longitude': -79.40374},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3397 Yonge Street',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4N 2M7',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['3397 Yonge Street', 'Toronto, ON M4N 2M7', 'Canada']},
#   'phone': '+14164883510',
#   'display_phone': '+1 416-488-3510',
#   'distance': 6504.139251918339},
#  {'id': 'Vg4N2DsGrzzoam9jS1L3Wg',
#   'alias': 'johnnys-hamburgers-toronto',
#   'name': "Johnny's Hamburgers",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6d2WCgGPofTXM3pOBafENA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/johnnys-hamburgers-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 258,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.77488, 'longitude': -79.3222399},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2595 Victoria Park Avenue',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M1T 1A4',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['2595 Victoria Park Avenue',
#     'Toronto, ON M1T 1A4',
#     'Canada']},
#   'phone': '+14164917222',
#   'display_phone': '+1 416-491-7222',
#   'distance': 12688.541427151731},
#  {'id': 'JytR7WvKyytDQNwOHUzSEg',
#   'alias': 'rudy-toronto-6',
#   'name': 'Rudy',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d8PSdBpFDKM9ASPWhlpEGA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rudy-toronto-6?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 87,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.64973, 'longitude': -79.38907},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '69 Duncan Street',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5V 2C5',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['69 Duncan Street', 'Toronto, ON M5V 2C5', 'Canada']},
#   'phone': '+14163510739',
#   'display_phone': '+1 416-351-0739',
#   'distance': 2762.5551017738135},
#  {'id': 'plmgqrS4LBxQgv2omXySXg',
#   'alias': 'rudy-toronto-9',
#   'name': 'Rudy',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YUWYJwbJyXR16_04_ptFtw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rudy-toronto-9?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 25,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.68235, 'longitude': -79.32924},
#   'transactions': [],
#   'location': {'address1': '1330 Danforth Avenue',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4J 1M9',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['1330 Danforth Avenue',
#     'Toronto, ON M4J 1M9',
#     'Canada']},
#   'phone': '+14169019110',
#   'display_phone': '+1 416-901-9110',
#   'distance': 5507.09005279422},
#  {'id': 'A115IN2JEevj_PoXechaVg',
#   'alias': 'rosies-burgers-toronto',
#   'name': "Rosie's Burgers",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QWLzQE_Sgd7f8uTfCsISZg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rosies-burgers-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 13,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.64758, 'longitude': -79.40097},
#   'transactions': [],
#   'location': {'address1': '573 Queen St W',
#    'address2': '',
#    'address3': None,
#    'city': 'Toronto',
#    'zip_code': 'M5V 2B6',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['573 Queen St W', 'Toronto, ON M5V 2B6', 'Canada']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2993.6552752992247},
#  {'id': 'xGXzIliuZ6FgMS870UjPRw',
#   'alias': 'the-burger-shack-toronto',
#   'name': 'The Burger Shack',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IrHBTNNdOSTS_00T2BE0YQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-burger-shack-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 122,
#   'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.70481, 'longitude': -79.4057},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '233 Eglinton Avenue W',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4R 1A9',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['233 Eglinton Avenue W',
#     'Toronto, ON M4R 1A9',
#     'Canada']},
#   'phone': '+14164871974',
#   'display_phone': '+1 416-487-1974',
#   'distance': 3470.194344900753},
#  {'id': 'Y0NkII8gne1QEJbUCBi2tg',
#   'alias': 'the-burgers-priest-toronto-4',
#   'name': "The Burger's Priest",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Qntj4TYmiMJIkE-XZtGPtw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-burgers-priest-toronto-4?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 166,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.6485688, 'longitude': -79.3874419},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '212 Adelaide Street W',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5H 1W7',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['212 Adelaide Street W',
#     'Toronto, ON M5H 1W7',
#     'Canada']},
#   'phone': '+16473477757',
#   'display_phone': '+1 647-347-7757',
#   'distance': 2957.0210851720053},
#  {'id': 'JrB6On8q8f1_ICQSCLg47w',
#   'alias': 'five-guys-toronto-5',
#   'name': 'Five Guys',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ds5gOL4FS-vJXeWpsTKIBA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/five-guys-toronto-5?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 163,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.657118, 'longitude': -79.380853},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '329 Yonge Street',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5B 1R7',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['329 Yonge Street', 'Toronto, ON M5B 1R7', 'Canada']},
#   'phone': '+14165910404',
#   'display_phone': '+1 416-591-0404',
#   'distance': 2300.4442970276673},
#  {'id': 'v_XG6rpmOIqxMYyTfNKjaQ',
#   'alias': 'square-boy-toronto',
#   'name': 'Square Boy',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3HND8nv3Cb5J0z4bjN1YGA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/square-boy-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 199,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.67974, 'longitude': -79.33945},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '875 Danforth Avenue',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4J 1L8',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['875 Danforth Avenue',
#     'Toronto, ON M4J 1L8',
#     'Canada']},
#   'phone': '+14164612571',
#   'display_phone': '+1 416-461-2571',
#   'distance': 4655.454638965249},
#  {'id': 'uMQV2qwiviaCA61tvEjmFQ',
#   'alias': 'retro-burger-toronto-3',
#   'name': 'Retro Burger',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nbtb0vMKyJ-FDJhXktL8Vg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/retro-burger-toronto-3?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 39,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 43.68408, 'longitude': -79.32131},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1684 Danforth Avenue',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4C 1H6',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['1684 Danforth Avenue',
#     'Toronto, ON M4C 1H6',
#     'Canada']},
#   'phone': '+16473467771',
#   'display_phone': '+1 647-346-7771',
#   'distance': 6167.567529897398},
#  {'id': 'vVm6vJRR6dnsv5pgwmxNyg',
#   'alias': 'simple-burger-toronto',
#   'name': 'Simple Burger',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4xzlavYeu5F-jOtng2rdpg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/simple-burger-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 10,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'poutineries', 'title': 'Poutineries'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.66334, 'longitude': -79.41863},
#   'transactions': [],
#   'location': {'address1': '735 Bloor St W',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M6G 1L5',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['735 Bloor St W', 'Toronto, ON M6G 1L5', 'Canada']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2132.0850980461496},
#  {'id': 'qEQO8zzmQ7R1iVHd0Ttjjw',
#   'alias': 'a-and-w-toronto-2',
#   'name': 'A&W',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xXbzPBmoItSBKWNWFWPVrg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/a-and-w-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 37,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 43.6630749476983,
#    'longitude': -79.3840788595245},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '496 Yonge Street',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4Y 1X9',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['496 Yonge Street', 'Toronto, ON M4Y 1X9', 'Canada']},
#   'phone': '+16473446616',
#   'display_phone': '+1 647-344-6616',
#   'distance': 1613.4257614295352},
#  {'id': 'tM7ybhItKjiIX6Kwcpk6wg',
#   'alias': 'rudy-toronto-13',
#   'name': 'RUDY',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SST1S6VCP6t4acDFy9Pz-g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rudy-toronto-13?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 27,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'poutineries', 'title': 'Poutineries'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.6195682, 'longitude': -79.5345326},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1466 The Queensway',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M8Z 1T5',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['1466 The Queensway', 'Toronto, ON M8Z 1T5', 'Canada']},
#   'phone': '+14162521177',
#   'display_phone': '+1 416-252-1177',
#   'distance': 12641.737613530046},
#  {'id': 'gOBxVkHpqtjRRxHBIrpnMA',
#   'alias': 'chipotle-mexican-grill-toronto',
#   'name': 'Chipotle Mexican Grill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7aVoRfvxkT1oVPFn4VubMA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chipotle-mexican-grill-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 246,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.65687204129381, 'longitude': -79.3808684},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '323 Yonge Street',
#    'address2': 'Unit 114',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5B 1R7',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['323 Yonge Street',
#     'Unit 114',
#     'Toronto, ON M5B 1R7',
#     'Canada']},
#   'phone': '+14165968600',
#   'display_phone': '+1 416-596-8600',
#   'distance': 2322.501495977673},
#  {'id': 'eBbAEg9DwtmTITdJylTD7A',
#   'alias': 'a-and-w-toronto-24',
#   'name': 'A&W',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8DeQC2-TbZ_yfJPMQ5GTwg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/a-and-w-toronto-24?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 21,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.6459842, 'longitude': -79.3899415},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '8 Mercer Street',
#    'address2': '',
#    'address3': None,
#    'city': 'Toronto',
#    'zip_code': 'M5V 0C4',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['8 Mercer Street', 'Toronto, ON M5V 0C4', 'Canada']},
#   'phone': '+16473481550',
#   'display_phone': '+1 647-348-1550',
#   'distance': 3194.8478400657827},
#  {'id': 'uklv_8iGhXk-Z_WukBdV_g',
#   'alias': 'fresh-burger-toronto-7',
#   'name': 'Fresh Burger',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c2CR9t7bcvWD14tfRtoluA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fresh-burger-toronto-7?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 28,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.76684, 'longitude': -79.41192},
#   'transactions': [],
#   'location': {'address1': '5025 Yonge Street',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M2N 5P2',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['5025 Yonge Street', 'Toronto, ON M2N 5P2', 'Canada']},
#   'phone': '+14169019018',
#   'display_phone': '+1 416-901-9018',
#   'distance': 10365.524860360927},
#  {'id': 'SOkat3uLjX__3-tCowhlHg',
#   'alias': 'rudy-toronto-5',
#   'name': 'Rudy',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e4j_xrF_uqcuTOKZ8Crc8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rudy-toronto-5?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 177,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.65489, 'longitude': -79.41474},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '619 College Street',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5V 2C5',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['619 College Street', 'Toronto, ON M5V 2C5', 'Canada']},
#   'phone': '+16477487839',
#   'display_phone': '+1 647-748-7839',
#   'distance': 2597.9277246385263},
#  {'id': 'hpte2mkCkY-CNg9OREQrMA',
#   'alias': 'a-and-w-toronto-6',
#   'name': 'A&W',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ou7CVZCtHi-sGizyiXZ1ig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/a-and-w-toronto-6?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 32,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 43.6491013, 'longitude': -79.3959291},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '372 Queen Street W',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5V 2A3',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['372 Queen Street W', 'Toronto, ON M5V 2A3', 'Canada']},
#   'phone': '+16473482600',
#   'display_phone': '+1 647-348-2600',
#   'distance': 2800.8767555724708},
#  {'id': '3FlkZKB0Gma6ss3G-aCiHg',
#   'alias': 'jasmin-sandwich-toronto-2',
#   'name': 'Jasmin Sandwich',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zqe6lYD6PPyfOeQEonScHw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jasmin-sandwich-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 17,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.7915098, 'longitude': -79.4182602},
#   'transactions': [],
#   'location': {'address1': '6119 Yonge st',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M2M 3W2',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['6119 Yonge st', 'Toronto, ON M2M 3W2', 'Canada']},
#   'phone': '+14166664442',
#   'display_phone': '+1 416-666-4442',
#   'distance': 13151.765044342967},
#  {'id': 'OAE8lSfTKJdA7s1zm-jDbg',
#   'alias': 'harveys-toronto-25',
#   'name': "Harvey's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V4lh6idbHX0-WymHtdH5dw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/harveys-toronto-25?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 19,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.6399525759499,
#    'longitude': -79.4190995272004},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '75 Hanna Avenue',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M6K 3N7',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['75 Hanna Avenue', 'Toronto, ON M6K 3N7', 'Canada']},
#   'phone': '+14165352662',
#   'display_phone': '+1 416-535-2662',
#   'distance': 4217.089877516608},
#  {'id': 'LTEVTg3qCGnlGaExZMAejw',
#   'alias': 'no-bull-burgers-toronto-2',
#   'name': 'No Bull Burgers',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zV0u9de52ZRE7qA2VmNjTw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/no-bull-burgers-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 103,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.68057, 'longitude': -79.28503},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1019 Kingston Road',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4E 1T3',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['1019 Kingston Road', 'Toronto, ON M4E 1T3', 'Canada']},
#   'phone': '+14166988131',
#   'display_phone': '+1 416-698-8131',
#   'distance': 9012.219453270656},
#  {'id': 't8yi2l7pZF43Rlf9_lHdDA',
#   'alias': 'hero-certified-burgers-king-and-yonge-toronto',
#   'name': 'Hero Certified Burgers - King & Yonge',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0NAvlScoH9Eh95NuwQjxWA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hero-certified-burgers-king-and-yonge-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 41,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 43.64953, 'longitude': -79.37773},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '79A Yonge Street',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5C 1S8',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['79A Yonge Street', 'Toronto, ON M5C 1S8', 'Canada']},
#   'phone': '+14163664376',
#   'display_phone': '+1 416-366-4376',
#   'distance': 3155.6518703324004},
#  {'id': 'xk_ivpAc_ow6JrQC7gZaMQ',
#   'alias': 'fresh-burger-toronto-4',
#   'name': 'Fresh Burger',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h2Jd4K-QMBgkoxvnndn3eA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fresh-burger-toronto-4?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 31,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 43.7873889, 'longitude': -79.4687563},
#   'transactions': [],
#   'location': {'address1': '1881 Steeles Avenue West',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M3H 5Y4',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['1881 Steeles Avenue West',
#     'Toronto, ON M3H 5Y4',
#     'Canada']},
#   'phone': '+16473518030',
#   'display_phone': '+1 647-351-8030',
#   'distance': 13738.513224232722},
#  {'id': 'pRBFVKqls5xdSLPYD9jWww',
#   'alias': 'a-and-w-toronto-28',
#   'name': 'A&W',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6kVT69L2R2Q0EC3SYuTE3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/a-and-w-toronto-28?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 10,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 43.76054, 'longitude': -79.32517},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1277 York Mills Road',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M3A 1Z5',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['1277 York Mills Road',
#     'Toronto, ON M3A 1Z5',
#     'Canada']},
#   'phone': '+14167929030',
#   'display_phone': '+1 416-792-9030',
#   'distance': 11217.409732700766},
#  {'id': 'J7zTx8hrZ3p1h_7JCdFthg',
#   'alias': 'five-guys-toronto-2',
#   'name': 'Five Guys',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lCn6ZuoHwTb7PGwjjvBbFw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/five-guys-toronto-2?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 6,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.64877, 'longitude': -79.38167},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '100 King Street W',
#    'address2': 'Space 93',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5X 1A9',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['100 King Street W',
#     'Space 93',
#     'Toronto, ON M5X 1A9',
#     'Canada']},
#   'phone': '+14168619900',
#   'display_phone': '+1 416-861-9900',
#   'distance': 3096.919156585045},
#  {'id': 'Mx8jCUdhaNbMgx_04DWHdA',
#   'alias': 'jacksons-burger-toronto-3',
#   'name': 'Jacksons Burger',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TLb-WazGiJLjOqH64DcKHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jacksons-burger-toronto-3?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 119,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.6574483915442,
#    'longitude': -79.3836816002438},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '38 Elm Street',
#    'address2': None,
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M5G 2K5',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['38 Elm Street', 'Toronto, ON M5G 2K5', 'Canada']},
#   'phone': '+16477485683',
#   'display_phone': '+1 647-748-5683',
#   'distance': 2149.5339533378437},
#  {'id': 'd16qDWj9zxpi0XGWBjZR8Q',
#   'alias': 'the-6-burger-bar-toronto',
#   'name': 'The 6 Burger Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/74ae-PGthuvQBRIQgWK3Rw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-6-burger-bar-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 41,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'poutineries', 'title': 'Poutineries'},
#    {'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 43.7253560736807,
#    'longitude': -79.2758500948548},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3 Chelwood Road',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M1K 2K5',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['3 Chelwood Road', 'Toronto, ON M1K 2K5', 'Canada']},
#   'phone': '+16473478436',
#   'display_phone': '+1 647-347-8436',
#   'distance': 11261.672893777943},
#  {'id': '3QRdvd5F6rnKzLLb1mIg6Q',
#   'alias': 'hero-certified-burgers-church-and-wellesley-toronto',
#   'name': 'Hero Certified Burgers - Church & Wellesley',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kJBWoPk1Q5vK0pX6Nn-TKg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hero-certified-burgers-church-and-wellesley-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 54,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 43.6655299, 'longitude': -79.38049},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '77 Wellesley Steet E',
#    'address2': '',
#    'address3': '',
#    'city': 'Toronto',
#    'zip_code': 'M4Y 1H7',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['77 Wellesley Steet E',
#     'Toronto, ON M4Y 1H7',
#     'Canada']},
#   'phone': '+14169729665',
#   'display_phone': '+1 416-972-9665',
#   'distance': 1618.625987735151},
#  {'id': 'PbCI9qi0peAzhA7R1xtQlg',
#   'alias': 'top-gun-steak-and-burgers-toronto',
#   'name': 'Top Gun Steak & Burgers',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KtQ7IvA9mVg2un-ssV_E2g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/top-gun-steak-and-burgers-toronto?adjust_creative=8XoX5Q1eKxWYyr9GSIo9MA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8XoX5Q1eKxWYyr9GSIo9MA',
#   'review_count': 50,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.74495, 'longitude': -79.29819},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1960 Lawrence Avenue E',
#    'address2': 'Unit 3',
#    'address3': None,
#    'city': 'Toronto',
#    'zip_code': 'M1R 2Z1',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['1960 Lawrence Avenue E',
#     'Unit 3',
#     'Toronto, ON M1R 2Z1',
#     'Canada']},
#   'phone': '+14167929440',
#   'display_phone': '+1 416-792-9440',
#   'distance': 11156.462945001262}]

# %%
tor_data=[]
queries=50
response=get_businesses("Toronto", "restaurants", queries, api_key)

for i in range (0, queries, 1):
    name=response[i]['name']
    address = response[i]['location']['address1']
    category=response[i]['categories'][0]['title']
    rating=response[i]['rating']
    review_count = response[i]['review_count']
    price_symbol = (response[i]).get('price')
    price_num = str(price_symbol).count('$')
    lat = response[i]['coordinates']['latitude']
    lon = response[i]['coordinates']['longitude']
    

    tor_data.append({"Restaurant Name":name,"Address":address,"Category":category,"Rating":rating,"Number of Reviews":review_count,"Price($)":price_symbol,"Price(num)":price_num,"Latitude":lat,"Longitude":lon})

tor_df=pd.DataFrame(tor_data)
len(tor_df)
# Out:
# 50

# %%
tor_df
# Out:
#                          Restaurant Name                   Address  \
# 0              Pai Northern Thai Kitchen          18 Duncan Street
# 1                       Richmond Station       1 Richmond Street W
# 2                                   Mira  420A Wellington Street W
# 3                                   Rasa         196 Robert Street
# 4                 KINKA IZAKAYA ORIGINAL         398 Church Street
# 5                                Katsuya       66 Gerrard Street E
# 6                                Aloette        163 Spadina Avenue
# 7                              Gusto 101       101 Portland Street
# 8           Seven Lives Tacos y Mariscos      72 Kensington Avenue
# 9           Mogouyan Hand-Pulled Noodles           124 Dundas St W
# 10          Holy Cow Japanese Steakhouse       254 Queen Street  W
# 11                     Trattoria Nervosa       75 Yorkville Avenue
# 12                                Byblos          11 Duncan Street
# 13                          Playa Cabana         111 Dupont Street
# 14                Ristorante Sotto Sotto           120 Avenue Road
# 15                             The Oxley      121 Yorkville Avenue
# 16                        Juicy Dumpling           280 Spadina Ave
# 17                            Fieramosca  36A Prince Arthur Avenue
# 18                       The Rabbit Hole      21 Adelaide Street W
# 19                     OEB Breakfast Co.      125 E Liberty Street
# 20                     Grandma Loves You         1084 Yonge Street
# 21              Steam Whistle Biergarten     255 Bremner Boulevard
# 22                                 AÑEJO      7 Marie Labatte Road
# 23                Three Monks and a Duck        811 Queen Street W
# 24                        Osteria Giulia           134 Avenue Road
# 25             Kingyo Fisherman's Market     51B Winchester Street
# 26                       Dzo Viet Eatery       308 Dundas Street W
# 27                                   Liu        533 College Street
# 28                           Library Bar        100 Front Street W
# 29                             Gusto 501         501 King Street E
# 30                 Soya Mandarin Kitchen         31 Baldwin Street
# 31                           Pearl Diver     100 Adelaide Street E
# 32                                Joso's        202 Davenport Road
# 33                            Ohiru Cafe        370 College Street
# 34                       Clay Restaurant           111 Queens Park
# 35               Manpuku Japanese Eatery         105 McCaul Street
# 36      New Orleans Seafood & Steakhouse         267 Scarlett Road
# 37                             1 Kitchen   550 Wellington Street W
# 38                        Eataly Toronto         55 Bloor Street W
# 39                        The MoMo House           1240 Bay Street
# 40                     Dirty Food Eatery      3070 Dundas Street W
# 41                  Famiglia Baldassarre          122 Geary Avenue
# 42  Cafe Landwer - Adelaide & University     165 University Avenue
# 43                             King Taps         100 King Street W
# 44                                PLANTA           1221 Bay Street
# 45                           Jin Dal Lae        647 Bloor Street W
# 46         Mogouyuan Hand-Pulled Noodles              760 Yonge St
# 47         Gyubee Japanese Grill - Bloor        335 Bloor Street W
# 48                       Sinjeon Topokki         377 Church Street
# 49      Her Father's Cider Bar & Kitchen        119 Harbord Street
#
#               Category  Rating  Number of Reviews Price($)  Price(num)  \
# 0                 Thai     4.5               3335       $$           2
# 1       Canadian (New)     4.5                869      $$$           3
# 2             Peruvian     4.5                256       $$           2
# 3       Canadian (New)     4.5                317       $$           2
# 4             Japanese     4.0               1790       $$           2
# 5             Japanese     4.5                478       $$           2
# 6               French     4.5                279      $$$           3
# 7              Italian     4.0               1100       $$           2
# 8              Mexican     4.5               1458        $           1
# 9              Noodles     4.5                 42     None           0
# 10         Steakhouses     4.5                139      $$$           3
# 11             Italian     4.0                384       $$           2
# 12       Mediterranean     4.5                890     $$$$           4
# 13             Mexican     4.0                467       $$           2
# 14             Italian     4.0                121      $$$           3
# 15          Gastropubs     4.0                167       $$           2
# 16             Dim Sum     4.5                594        $           1
# 17             Italian     4.5                110      $$$           3
# 18          Gastropubs     4.0                 27     None           0
# 19  Breakfast & Brunch     4.5                 93       $$           2
# 20          Sandwiches     5.0                 72       $$           2
# 21              German     4.5                 23     None           0
# 22             Mexican     4.0                 20     None           0
# 23          Vegetarian     4.0                 79     None           0
# 24             Italian     4.0                 23     None           0
# 25     Seafood Markets     5.0                  5     None           0
# 26          Vietnamese     4.0                131       $$           2
# 27            Desserts     4.5                  2     None           0
# 28             Lounges     4.0                121      $$$           3
# 29             Italian     4.0                 55     None           0
# 30             Chinese     4.5                 31     None           0
# 31             Seafood     4.0                619       $$           2
# 32             Seafood     4.5                165      $$$           3
# 33  Breakfast & Brunch     5.0                  7     None           0
# 34      Canadian (New)     4.0                 20     None           0
# 35            Japanese     4.0                512        $           1
# 36             Seafood     4.5                162      $$$           3
# 37       Cocktail Bars     4.5                 33     None           0
# 38             Italian     3.5                270       $$           2
# 39  Himalayan/Nepalese     4.5                 21     None           0
# 40  Breakfast & Brunch     4.5                130       $$           2
# 41             Italian     4.5                 67       $$           2
# 42               Cafes     4.0                485       $$           2
# 43      Canadian (New)     4.0                384       $$           2
# 44  Tapas/Small Plates     4.0                488       $$           2
# 45              Korean     4.5                109       $$           2
# 46             Noodles     4.0                 77       $$           2
# 47            Barbeque     4.0                307      $$$           3
# 48              Korean     4.5                  2     None           0
# 49          Gastropubs     4.5                183       $$           2
#
#      Latitude  Longitude
# 0   43.647840 -79.388720
# 1   43.651373 -79.379285
# 2   43.644170 -79.396390
# 3   43.662775 -79.403968
# 4   43.660424 -79.378900
# 5   43.659950 -79.378820
# 6   43.648558 -79.395963
# 7   43.645002 -79.400309
# 8   43.654490 -79.400830
# 9   43.655730 -79.384490
# 10  43.649930 -79.391450
# 11  43.671010 -79.391040
# 12  43.647546 -79.388123
# 13  43.675958 -79.401184
# 14  43.673740 -79.396460
# 15  43.670717 -79.393126
# 16  43.652520 -79.398540
# 17  43.669630 -79.397190
# 18  43.649950 -79.379760
# 19  43.638356 -79.416202
# 20  43.677846 -79.390108
# 21  43.640853 -79.385279
# 22  43.734110 -79.345570
# 23  43.646050 -79.408970
# 24  43.674310 -79.396680
# 25  43.665845 -79.368093
# 26  43.654450 -79.391780
# 27  43.655628 -79.411114
# 28  43.646172 -79.381136
# 29  43.654640 -79.359500
# 30  43.655880 -79.393290
# 31  43.651630 -79.373750
# 32  43.675110 -79.396070
# 33  43.657258 -79.404682
# 34  43.667980 -79.393470
# 35  43.654060 -79.391010
# 36  43.677750 -79.506110
# 37  43.643133 -79.401996
# 38  43.669615 -79.388795
# 39  43.670327 -79.390157
# 40  43.665650 -79.471880
# 41  43.670520 -79.435060
# 42  43.648750 -79.384910
# 43  43.648638 -79.381744
# 44  43.670215 -79.389434
# 45  43.664166 -79.415170
# 46  43.669430 -79.386710
# 47  43.667160 -79.400470
# 48  43.661150 -79.378690
# 49  43.662320 -79.404530

# %%
tor_df.to_csv('Data/tor_data.csv', index=False)
